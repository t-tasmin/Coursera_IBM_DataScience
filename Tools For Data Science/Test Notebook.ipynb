# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Tania Tasmin**
# Data Scientist

# %% [markdown]
# *I am interested in data science because I am passionate about both programming and Mathematics. Data science is a perfect career which combine these two fields.*

# %% [markdown]
# ### The above cells are used as markdown cells where we can insert text, figure etc. In the cell below, we will write a short code that can be run/ executed and display output.

# %%
1+1
# Out:
# 2

# %% [markdown]
# **This is a picture**
#
# ![Math.jpg](attachment:Math.jpg  "Jupyter Notebook Logo")
#
# **This is a numbered list**
#
# 1. Item 1
# 2. Item 2
# 3. Item 3
#
# **This is a unordered list**
# - Item 1
# - Item 2
# - Item 3
#
# **This is a table**
#
# |Column 1|Column 2| Column 3|
# |--------|:------:|---------|
# |Item 1  | Item 2 | Item 3  |
# |Item 4  | Item 5 | Item 6  |
